# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

labels = ['FirstChoice','RandomRestart','SteepestRandom','SimulatedAnnealing']
values1 = [12.284950453999954, 2232.088454417, 20.812975529999676, 2750.8452466470007]
values2 = [0.94,0.935,0.956,0.897]

fig, ax = plt.subplots(2,1,figsize=(16, 12))

bars = ax[0].bar(labels, values1, color=sns.color_palette("tab20", len(labels)))

for bar, val in zip(bars, values1):
    yval = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width()/2, yval + 0.1, f'{val:.2f}', 
            ha='center', va='bottom', fontsize=10, color='black')

ax[0].set_xlabel("Thuật toán", fontsize=12)
ax[0].set_ylabel("Thời gian (s)", fontsize=12)
ax[0].set_title("Thời gian giải quyết 8 Queens trong 1000 lần thử", fontsize=16)

bars = ax[1].bar(labels,values2,color=sns.color_palette("tab20",len(labels)))

for bar,val in zip(bars,values2):
    yval = bar.get_height()
    ax[1].text(bar.get_x()+bar.get_width()/2,yval+0.01,val,
               ha='center',va='bottom',fontsize=10,color='black')
    
ax[1].set_xlabel("Thuật toán",fontsize=12)
ax[1].set_ylabel("Tỉ lệ thành công",fontsize=12)
ax[1].set_title("Tỉ lệ thành công 8 Queens trong 1000 lần thử",fontsize=16)

plt.savefig('8 Queens.png',dpi=300,bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

labels = ['FirstChoice','RandomRestart','SteepestRandom','SimulatedAnnealing']
values1 = [17.58018670799902, 1154.6121927129989, 0.040640808998432476, 2940.200461815002]
values2 = [0.001,0.471,0.001,0.466]

fig, ax = plt.subplots(2,1,figsize=(16, 12))

bars = ax[0].bar(labels, values1, color=sns.color_palette("tab20b", len(labels)))

for bar, val in zip(bars, values1):
    yval = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width()/2, yval + 0.1, f'{val:.2f}', 
            ha='center', va='bottom', fontsize=10, color='black')

ax[0].set_xlabel("Thuật toán", fontsize=12)
ax[0].set_ylabel("Thời gian (s)", fontsize=12)
ax[0].set_title("Thời gian giải quyết 8 Puzzle trong 1000 lần thử", fontsize=16)

bars = ax[1].bar(labels,values2,color=sns.color_palette("tab20b",len(labels)))

for bar,val in zip(bars,values2):
    yval = bar.get_height()
    ax[1].text(bar.get_x()+bar.get_width()/2,yval+0.01,val,
               ha='center',va='bottom',fontsize=10,color='black')
    
ax[1].set_xlabel("Thuật toán",fontsize=12)
ax[1].set_ylabel("Tỉ lệ thành công",fontsize=12)
ax[1].set_title("Tỉ lệ thành công 8 Puzzle trong 1000 lần thử",fontsize=16)

plt.savefig('8 Puzzle.png',dpi=300,bbox_inches='tight')

plt.show()
